# %%
# The code was removed by Watson Studio for sharing.
# Out:
#      X           Y
# 0   80  140.678111
# 1   43   51.524027
# 2   93  107.434531
# 3  100  191.212173
# 4   70   99.607441

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=df_data_0.X,y=df_data_0.Y)
plt.xlim(0)
plt.ylim(0)
plt.grid()
plt.xlabel("Days after inoculation")
plt.ylabel("Area")
# Out:
# Text(0, 0.5, 'Area')
